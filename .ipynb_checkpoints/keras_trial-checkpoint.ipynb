# %% [markdown]
# ## Preprocess

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from random import randint
from tqdm import tqdm

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
labels = pd.read_csv('data/labels.csv')

# %%
data_length = len(labels)
breed = set(labels['breed'])
class_length = len(breed)
class_to_num = dict(zip(breed, range(class_length)))
num_to_class = dict(zip(range(class_length), breed))

# %%
width = 299
X = np.zeros((data_length, width, width, 3),dtype=np.uint8)
y = np.zeros((data_length, class_length),dtype=np.uint8)

for i in tqdm(range(data_length)):
    X[i] = cv2.resize(cv2.imread('data/train/{}.jpg'.format(labels['id'][i])),(width,width))
    y[i][class_to_num[labels['breed'][i]]] = 1
# Out:
# 100%|██████████| 10222/10222 [01:22<00:00, 123.82it/s]

# %%
plt.figure(figsize=(12,6))
for i in range(8):
    index = randint(0,data_length-1)
    plt.subplot(2,4,i+1)
    plt.imshow(X[index][:,:,::-1])
    plt.title(num_to_class[y[index].argmax()])

# %% [markdown]
# ## Keras Implementation

# %%
import pickle
from keras.layers import *
from keras.models import *
from keras.applications import *
from keras.optimizers import *
from keras.regularizers import *
from keras.applications.inception_v3 import preprocess_input

# %%
def feature_extraction(core_model, data=X):
    model = core_model(include_top=False, input_shape=(width,width,3), weights='imagenet')
    inputs = Input((width, width, 3))
    x = inputs
    x = Lambda(preprocess_input, name='preprocessing')(x)
    x = model(x)
    x = GlobalAveragePooling2D()(x)
    model = Model(inputs,x)
    features = model.predict(data, batch_size=64, verbose=1)
    return features

# %%
inception_features = feature_extraction(InceptionV3, X)
# Out:
# 10222/10222 [==============================] - 6520s

# %%
np.save('data/inception_features_file.npy', inception_features)

# %%
xception_features = feature_extraction(Xception, X)

# %%
features_save = open('data/xception_features.p','w')
pickle.dump(xception_features, features_save)

# %%
inputs = Input(feaures.shape[1:])
x = inputs
x = Dropout(0.5)(x)
x = Dense(class_length, activation='softmax')(x)
